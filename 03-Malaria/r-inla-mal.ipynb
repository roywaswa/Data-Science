# %% [markdown]
# # R-INLA For Malaria in Western Nyanza Kenya

# %%
spatial_packages <- c(
  "tidyverse", "sf", "terra", "raster", "sp", 
  "spdep", "gstat", "rgeos", "spBayes","ggspatial"
)

# %%
# library(tidyverse)
library(sf)
# library(terra)
# Out:
# Error in `library()`:
#
# ! there is no package called ‘sf’
#
#     ▆
#
#  1. └─base::library(sf)

# %%
# load files
mal_2015_path <- "exports/malaria_2015_selected.csv"
mal_2020_path <- "exports/malaria_2020_selected.csv"
mal_2015 <- read_csv(mal_2015_path)
mal_2020 <- read_csv(mal_2020_path)

# load shapefiles
# Out:
# Error in `read_csv()`:
#
# ! could not find function "read_csv"
